# %% [markdown]
# To use this jupyter notebook you will have to create a conda environment and install matplotlib into that environment.
#
# You can do this with the following:
#
# 1) login to Hopper with SSH
#
# 2) module load miniconda3
#
# 3) conda create --name plotting matplotlib
#
# 4) Once the install is complete login to https://hopper.alliance.unm.edu:8000 and change kernels to "Python [conda-env::conda-plotting]" using the "Kernel" menu.

# %% [markdown]
# ## Problem 2

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
# Quicksort: 100000000
# Other one: 1.6k all round

types = ['Quicksort', 'Quicksort -O1', 'Quicksort -O2', 'Quicksort -O3', 'Matrix Multiply', 'Matrix Multiply -O1', 'Matrix Multiply -O2', 'Matrix Multiply -O3']
times = [22.628712, 22.727719, 24.188713, 23.207803, 17.257537, 16.932407, 16.865180, 16.667327]
bar_colors = ['tab:green', 'tab:green', 'tab:green', 'tab:green', 'tab:green', 'tab:green', 'tab:green']

ax.bar(types, times, color=bar_colors)

ax.set_ylabel('Time (s)')
plt.xticks(rotation=30)

# Save the figure to an EPS file
plt.savefig('Problem1.eps', format='eps')

# %% [markdown]
# ## Problem 3

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
# Quicksort: 100000000
# Other one: 1.6k all round

types = ['Quicksort', 'Quicksort -O1', 'Quicksort -O2', 'Quicksort -O3', 'Matrix Multiply', 'Matrix Multiply -O1', 'Matrix Multiply -O2', 'Matrix Multiply -O3']
times = [8.546931, 8.800083, 9.343215, 8.737870, 5.577870, 5.466625, 5.540625, 5.425029]
bar_colors = ['tab:blue', 'tab:blue', 'tab:blue', 'tab:blue', 'tab:blue', 'tab:blue', 'tab:blue', 'tab:blue']

ax.bar(types, times, color=bar_colors)

ax.set_ylabel('Time (s)')
plt.xticks(rotation=30)

# Save the figure to an EPS file
plt.savefig('Problem2.eps', format='eps')

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
# Quicksort: 100000000
# Other one: 1.6k all round

types = ['Quicksort', 'Quicksort -O1', 'Quicksort -O2', 'Quicksort -O3', 'Matrix Multiply', 'Matrix Multiply -O1', 'Matrix Multiply -O2', 'Matrix Multiply -O3']
times = []
bar_colors = ['tab:green', 'tab:green', 'tab:green', 'tab:green', 'tab:green', 'tab:green', 'tab:green']

ax.bar(types, times, color=bar_colors)

ax.set_ylabel('Time (s)')
plt.xticks(rotation=30)

# Save the figure to an EPS file
plt.savefig('Problem1.eps', format='eps')

# %%
# fig 1: matrix mult on cluster
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
# Quicksort: 100000000
# Other one: 1.6k all round

types = ['Matrix Multiply', 'Matrix Multiply -O1', 'Matrix Multiply -O2', 'Matrix Multiply -O3']
times = [33.429890, 8.856118, 8.727831, 8.784279]
bar_colors = ['tab:green', 'tab:green', 'tab:green', 'tab:green', 'tab:green', 'tab:green', 'tab:green']

ax.bar(types, times, color=bar_colors)

ax.set_ylabel('Time (s)')
plt.xticks(rotation=30)

# Save the figure to an EPS file
plt.savefig('Problem1.eps', format='eps')

# %%
# fig 2: quick sort on cluster
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
# Quicksort: 100000000
# Other one: 1.6k all round

types = ['Quicksort', 'Quicksort -O1', 'Quicksort -O2', 'Quicksort -O3']
times = [27.358997, 9.835342, 10.365400, 10.392644]
bar_colors = ['tab:green', 'tab:green', 'tab:green', 'tab:green', 'tab:green', 'tab:green', 'tab:green']

ax.bar(types, times, color=bar_colors)

ax.set_ylabel('Time (s)')
plt.xticks(rotation=30)

# Save the figure to an EPS file
plt.savefig('Problem2.eps', format='eps')

# %%
# fig 3: is quick sort and matrix multiply for both compilers on hopper
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
# Quicksort: 100000000
# Other one: 1.6k all round

types = ['Q-intel', 'Q-intel -O1', 'Q-intel -O2', 'Q-intel -O3', 'Q-gcc', 'Q-gcc -O1', 'Q-gcc -O2', 'Q-gcc -O3']
times = [22.787822, 10.285975, 8.735149, 8.534124, 23.221312, 10.921483, 9.098028, 10.357528]
bar_colors = ['tab:blue', 'tab:blue', 'tab:blue', 'tab:blue', 'tab:green', 'tab:green', 'tab:green', 'tab:green']

ax.bar(types, times, color=bar_colors)

ax.set_ylabel('Time (s)')
plt.xticks(rotation=30)

# Save the figure to an EPS file
plt.savefig('Problem3.eps', format='eps')
